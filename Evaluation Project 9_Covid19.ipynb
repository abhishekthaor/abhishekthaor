# %% [markdown]
# # Covid19 Dataset Analysis

# %% [raw]
# This table contains an aggregation of each USA State level data.
#
#
# Field description of Attribute:
#
# 1.Province_State - The name of the State within the USA.
# 2.Country_Region - The name of the Country (US).
# 3.Last_Update - The most recent date the file was pushed.
# 4.Lat - Latitude.
# 5.Long_ - Longitude.
# 6.Confirmed - Aggregated confirmed case count for the state.
# 7.Deaths - Aggregated Death case count for the state.
# 8.Recovered - Aggregated Recovered case count for the state.
# 9.Active - Aggregated confirmed cases that have not been resolved (Active = Confirmed - Recovered - Deaths).
# 10.FIPS - Federal Information Processing Standards code that uniquely identifies counties within the USA.
# 11.Incident_Rate - confirmed cases per 100,000 persons.
# 12.People_Tested - Total number of people who have been tested.
# 13.People_Hospitalized - Total number of people hospitalized.
# 14.Mortality_Rate - Number recorded deaths * 100/ Number confirmed cases.
# 15.UID - Unique Identifier for each row entry.
# 16.ISO3 - Officialy assigned country code identifiers.
# 17.Testing_Rate - Total number of people tested per 100,000 persons.
# 18.Hospitalization_Rate - Total number of people hospitalized * 100/ Number of confirmed cases.
#
# Problem Statement:  To identify the deaths and recovered cases
#
# Approach: We would be taking Mortality Rate as our "Target Variable" as is influenced by other metioned attributes in dataset and try buliding a model to predict the desired outcome

# %%
import pandas as pd
df=pd.read_csv("covid19_dataset.csv")
df.head()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 0         Alabama             US  2020-05-21 02:32:54  32.3182  -86.9023
# 1          Alaska             US  2020-05-21 02:32:54  61.3707 -152.4044
# 2  American Samoa             US  2020-05-21 02:32:54 -14.2710 -170.1320
# 3         Arizona             US  2020-05-21 02:32:54  33.7298 -111.4312
# 4        Arkansas             US  2020-05-21 02:32:54  34.9697  -92.3731
#
#    Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 0      13052     522        NaN  12530.0     1     266.194321       164450.0
# 1        401      10      352.0     39.0     2      54.815493        37045.0
# 2          0       0        NaN      0.0    60       0.000000          124.0
# 3      14906     747     3773.0  10386.0     4     204.788838       165435.0
# 4       5003     107     3852.0   1044.0     5     165.782801        96258.0
#
# ...

# %%
df.shape
# Out:
# (58, 18)

# %% [markdown]
# # Importing Required Libraries for EDA

# %%
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Description

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     object
#  1   Country_Region        58 non-null     object
#  2   Last_Update           58 non-null     object
#  3   Lat                   56 non-null     float64
#  4   Long_                 56 non-null     float64
#  5   Confirmed             58 non-null     int64
#  6   Deaths                58 non-null     int64
#  7   Recovered             42 non-null     float64
#  8   Active                58 non-null     float64
#  9   FIPS                  58 non-null     int64
#  10  Incident_Rate         56 non-null     float64
#  11  People_Tested         56 non-null     float64
#  12  People_Hospitalized   33 non-null     float64
#  13  Mortality_Rate        57 non-null     float64
#  14  UID                   58 non-null     int64
# ...

# %% [markdown]
# # Checking for Missing Data

# %%
df.isnull().sum()
# Out:
# Province_State           0
# Country_Region           0
# Last_Update              0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered               16
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate    25
# dtype: int64

# %% [raw]
# Since few Columns do not effect the outcome of mortality rate the same can be dropped

# %%
df.drop(["Country_Region","Last_Update","Lat","Long_","FIPS","UID","ISO3"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Province_State  Confirmed  Deaths    Recovered   Active  Incident_Rate  \
# 0         Alabama      13052     522  7007.428571  12530.0     266.194321
# 1          Alaska        401      10   352.000000     39.0      54.815493
# 2  American Samoa          0       0  7007.428571      0.0       0.000000
# 3         Arizona      14906     747  3773.000000  10386.0     204.788838
# 4        Arkansas       5003     107  3852.000000   1044.0     165.782801
#
#    People_Tested  People_Hospitalized  Mortality_Rate  Testing_Rate  \
# 0       164450.0               1493.0        3.999387   3353.942386
# 1        37045.0                  NaN        2.493766   5063.940017
# 2          124.0                  NaN             NaN    222.857246
# 3       165435.0               1792.0        5.011405   2272.859351
# 4        96258.0                535.0        2.138717   3189.670370
#
#    Hospitalization_Rate
# 0             11.438860
# 1                   NaN
# 2                   NaN
# ...

# %%
df.shape
# Out:
# (58, 11)

# %%
df.isnull().sum()
# Out:
# Province_State          0
# Confirmed               0
# Deaths                  0
# Recovered               0
# Active                  0
# Incident_Rate           0
# People_Tested           0
# People_Hospitalized     0
# Mortality_Rate          0
# Testing_Rate            0
# Hospitalization_Rate    0
# dtype: int64

# %% [markdown]
# # Replacing Missing Data

# %%
df['Incident_Rate']=df["Incident_Rate"].fillna((df["Incident_Rate"].mean()))

# %%
df['People_Tested']=df["People_Tested"].fillna((df["People_Tested"].mean()))

# %%
df['People_Hospitalized']=df["People_Hospitalized"].fillna((df["People_Hospitalized"].mean()))

# %%
df['Testing_Rate']=df["Testing_Rate"].fillna((df["Testing_Rate"].mean()))

# %%
df['Hospitalization_Rate']=df["Hospitalization_Rate"].fillna((df["Hospitalization_Rate"].mean()))

# %%
df['Mortality_Rate']=df["Mortality_Rate"].fillna((df["Mortality_Rate"].mean()))

# %%
df.isnull().sum()
# Out:
# Province_State          0
# Confirmed               0
# Deaths                  0
# Recovered               0
# Active                  0
# Incident_Rate           0
# People_Tested           0
# People_Hospitalized     0
# Mortality_Rate          0
# Testing_Rate            0
# Hospitalization_Rate    0
# dtype: int64

# %%
df.describe(include="all")
# Out:
#         Province_State      Confirmed        Deaths     Recovered  \
# count               58      58.000000     58.000000     58.000000
# unique              58            NaN           NaN           NaN
# top     Grand Princess            NaN           NaN           NaN
# freq                 1            NaN           NaN           NaN
# mean               NaN   26756.086207   1611.017241   7007.428571
# std                NaN   52562.031122   4084.750891   9901.304545
# min                NaN       0.000000      0.000000     13.000000
# 25%                NaN    2596.000000     74.000000   1281.750000
# 50%                NaN   10148.500000    385.000000   4987.000000
# 75%                NaN   29395.500000   1394.250000   7007.428571
# max                NaN  354370.000000  28636.000000  61886.000000
#
#                Active  Incident_Rate  People_Tested  People_Hospitalized  \
# count       58.000000      58.000000   5.800000e+01            58.000000
# ...

# %% [markdown]
# # Data Visualization

# %%
sb.distplot(df["Mortality_Rate"])
plt.title("Mortality_Rate")
plt.show()

# %%
plt.figure(figsize=(20,16))
sb.barplot(x="Province_State", y="Mortality_Rate",data=df)
plt.xticks(rotation="vertical")
plt.title("Mortality Rate in each Province")
# Out:
# Text(0.5, 1.0, 'Mortality Rate in each Province')

# %%
plt.figure(figsize=(20,16))
sb.barplot(x="Province_State", y="Deaths",data=df)
plt.xticks(rotation="vertical")
plt.title("Deaths in each Province")
# Out:
# Text(0.5, 1.0, 'Deaths in each Province')

# %%
plt.figure(figsize=(20,16))
sb.barplot(x="Province_State", y="People_Tested",data=df)
plt.xticks(rotation="vertical")
plt.title("People Tested in each Province")
# Out:
# Text(0.5, 1.0, 'People Tested in each Province')

# %%
plt.figure(figsize=(20,16))
sb.barplot(x="Province_State", y="People_Hospitalized",data=df)
plt.xticks(rotation="vertical")
plt.title("People Hospitalized in each Province")
# Out:
# Text(0.5, 1.0, 'People Hospitalized in each Province')

# %%
plt.figure(figsize=(20,16))
sb.barplot(x="Province_State", y="Testing_Rate",data=df)
plt.xticks(rotation="vertical")
plt.title("Testing Rate in each Province")
# Out:
# Text(0.5, 1.0, 'Testing Rate in each Province')

# %%
plt.figure(figsize=(20,16))
sb.barplot(x="Province_State", y="Hospitalization_Rate",data=df)
plt.xticks(rotation="vertical")
plt.title("Hospitalization Rate in each Province")
# Out:
# Text(0.5, 1.0, 'Hospitalization Rate in each Province')

# %% [markdown]
# # Relation between Mortality Rate, Comfirmed Cases, People Tested and People Hospitalised

# %%
import warnings
warnings.filterwarnings('ignore')
sb.pairplot(df, x_vars=['Confirmed', 'People_Tested', 'People_Hospitalized'], y_vars='Mortality_Rate', size=5, aspect=1, kind='reg')

# %%
sb.pairplot(df, x_vars=['Confirmed'], y_vars='Deaths', size=5, aspect=1, kind='reg')

# %%
df.corr()
# Out:
#                       Confirmed    Deaths  Recovered    Active  Incident_Rate  \
# Confirmed              1.000000  0.982191   0.822547  0.985218       0.708436
# Deaths                 0.982191  1.000000   0.830223  0.954378       0.710105
# Recovered              0.822547  0.830223   1.000000  0.725085       0.542795
# Active                 0.985218  0.954378   0.725085  1.000000       0.700926
# Incident_Rate          0.708436  0.710105   0.542795  0.700926       1.000000
# People_Tested          0.824136  0.739634   0.711255  0.826144       0.441669
# People_Hospitalized    0.869267  0.908279   0.761829  0.835938       0.551076
# Mortality_Rate         0.382537  0.427127   0.322160  0.367626       0.353882
# Testing_Rate           0.332464  0.344465   0.220597  0.321395       0.620621
# Hospitalization_Rate   0.287471  0.298225   0.231692  0.284564       0.196029
#
#                       People_Tested  People_Hospitalized  Mortality_Rate  \
# ...

# %%
corr=df.corr()
plt.figure(figsize=(16,8))
sb.heatmap(corr,annot=True, linewidths=2, fmt=".2f")
plt.show()

# %% [markdown]
# Mortality Rate is correlated with Incident Rate, Testing Rate, Hospitalisation rate, Confirmed and Active Cases. Hence, mortality rate is our target Variable

# %% [markdown]
# # Determining Liner Regression Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %%
df.drop(["Province_State"], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Confirmed', 'Deaths', 'Recovered', 'Active', 'Incident_Rate',
#        'People_Tested', 'People_Hospitalized', 'Mortality_Rate',
#        'Testing_Rate', 'Hospitalization_Rate'],
#       dtype='object')

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(df)
df_scaler = scaler.transform(df)
df_scaled= pd.DataFrame(df_scaler)
df_scaled.columns= ['Confirmed', 'Deaths', 'Recovered', 'Active',
       'Incident_Rate', 'People_Tested', 'People_Hospitalized',
       'Mortality_Rate', 'Testing_Rate', 'Hospitalization_Rate']
df_scaled
# Out:
#     Confirmed    Deaths  Recovered    Active  Incident_Rate  People_Tested  \
# 0   -0.262999 -0.268934   0.000000 -0.184202  -3.316157e-01      -0.211042
# 1   -0.505788 -0.395373  -0.678048 -0.489329  -8.706685e-01      -0.648930
# 2   -0.513484 -0.397843   0.000000 -0.490281  -1.010458e+00      -0.775826
# 3   -0.227419 -0.213370  -0.329520 -0.236575  -4.882104e-01      -0.207656
# 4   -0.417470 -0.371419  -0.321472 -0.464779  -5.876826e-01      -0.445416
# 5    1.136910  0.465746   0.000000  1.525002  -4.554209e-01       3.967184
# 6   -0.075980 -0.077053  -0.359574 -0.050094  -9.249085e-04      -0.323132
# 7    0.235303  0.473648  -0.075740  0.223593   1.780346e+00      -0.120759
# 8   -0.356231 -0.321288  -0.309959 -0.394549   1.135455e+00      -0.620172
# 9   -0.512544 -0.397843   0.000000 -0.489084   2.899212e-16       0.000000
# 10  -0.368571 -0.297333  -0.606019 -0.341639   1.718043e+00      -0.637333
# ...

# %%
lr=LinearRegression()

# %%
considered_cols= ['Confirmed','Recovered','Active','Incident_Rate','Testing_Rate', 'Hospitalization_Rate']
x = df_scaled[considered_cols]
x
# Out:
#     Confirmed  Recovered    Active  Incident_Rate  Testing_Rate  \
# 0   -0.262999   0.000000 -0.184202  -3.316157e-01     -0.286981
# 1   -0.505788  -0.678048 -0.489329  -8.706685e-01      0.621380
# 2   -0.513484   0.000000 -0.490281  -1.010458e+00     -1.950231
# 3   -0.227419  -0.329520 -0.236575  -4.882104e-01     -0.861258
# 4   -0.417470  -0.321472 -0.464779  -5.876826e-01     -0.374243
# 5    1.136910   0.000000  1.525002  -4.554209e-01     -0.213169
# 6   -0.075980  -0.359574 -0.050094  -9.249085e-04     -0.852504
# 7    0.235303  -0.075740  0.223593   1.780346e+00      0.772966
# 8   -0.356231  -0.309959 -0.394549   1.135455e+00      0.408692
# 9   -0.512544   0.000000 -0.489084   2.899212e-16      0.000000
# 10  -0.368571  -0.606019 -0.341639   1.718043e+00      0.973658
# 11   0.397546   0.000000  0.618125  -4.468073e-01     -0.160851
# 12   0.250349   0.000000  0.440511  -5.448659e-02     -0.052645
# 13  -0.511507   0.000000 -0.487838   2.899212e-16      0.000000
# ...

# %%
y =df_scaled.Mortality_Rate
y
# Out:
# 0    -2.187272e-01
# 1    -9.364182e-01
# 2     4.233718e-16
# 3     2.636756e-01
# 4    -1.105661e+00
# 5    -1.867739e-01
# 6     5.910142e-01
# 7     2.186279e+00
# 8    -3.217513e-01
# 9    -2.125132e+00
# 10    4.441491e-01
# 11   -2.045921e-02
# 12   -9.273031e-02
# 13   -7.367604e-01
# 14   -5.774883e-01
# 15   -8.648735e-01
# 16   -6.604905e-01
# 17    2.284044e-02
# 18    9.100555e-01
# 19   -9.258171e-01
# 20   -9.932618e-01
# 21    6.942557e-02
# 22    1.394990e+00
# 23   -2.121457e-01
# 24    2.659542e-01
# 25    1.124847e+00
# 26    2.424985e+00
# 27   -4.781363e-03
# 28    1.453144e-01
# 29    5.212205e-01
# 30   -5.295697e-01
# 31   -1.533682e+00
# 32    3.072745e-01
# 33    2.163392e-01
# 34    1.273135e+00
# 35    1.035655e-02
# 36    1.726787e+00
# 37   -4.171787e-01
# 38   -1.010238e+00
# 39    2.414623e+00
# 40    7.589447e-01
# 41    4.512527e-01
# 42   -3.192627e-01
# 43    1.212413e+00
# 44   -4.612709e-02
# 45   -2.050156e-01
# 46   -1.062063e-02
# ...

# %%
def split(x,y):
    return train_test_split(x, y, test_size=0.20, random_state=14)

# %%
X_train, X_test, y_train, y_test=split(x,y)
print('Train cases as below')
print('X_train shape: ',x_train.shape)
print('y_train shape: ',y_train.shape)
print('\nTest cases as below')
print('X_test shape: ',x_test.shape)
print('y_test shape: ',y_test.shape)
# Out:
# Train cases as below
# X_train shape:  (46, 6)
# y_train shape:  (46,)
#
# Test cases as below
# X_test shape:  (12, 6)
# y_test shape:  (12,)

# %%
lr.fit=(x_train,y_train)
lr.coef_
lr.intercept_
lr.score(x_train,y_train)
pred=lr.predict(x_test)
print("Error:")
print("Mean Absolute error:",mean_absolute_error(y_test, pred))
print("Mean Squared error:",mean_squared_error(y_test, pred))
print("Root Mean Squared error:",np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# Error:
# Mean Absolute error: 0.9949153984395559
# Mean Squared error: 1.567604579289732
# Root Mean Squared error: 1.252040166803658

# %%
lr.coef_
# Out:
# array([ 0.86898633,  0.03805659, -0.69436044,  0.27381246, -0.19631638,
#         0.25821015])

# %%
lr.intercept_
# Out:
# -0.06843495394917964

# %%
# co-efficient of determination
from sklearn.metrics import r2_score
print("R2 Score:",r2_score(y_test, pred))
# Out:
# R2 Score: -0.8741681499751563

# %%
considered_cols.insert(0,'Intercept')
coef = lr.coef_.tolist()
coef.insert(0, lr.intercept_)

# %%
eq1 = zip(considered_cols, coef)

for c1,c2 in eq1:
    print(c1,c2)
# Out:
# Intercept -0.06843495394917964
# Confirmed 0.8689863314055135
# Recovered 0.03805658579739396
# Active -0.6943604368657337
# Incident_Rate 0.2738124599171865
# Testing_Rate -0.19631638286734773
# Hospitalization_Rate 0.2582101471071951

# %% [markdown]
# Y = -0.06 + (Confirmed * 0.86) + (Recovered * 0.03) - (Active * 0.69) + (Incident_Rate * 0.27) - (Testing_Rate * -0.19) + (Hospitalization_Rate * -0.25.

# %% [markdown]
# # Model Saving

# %%
import pickle
filename="Project9_Covid19.pkl"
pickle.dump(ls,open(filename,"wb"))
